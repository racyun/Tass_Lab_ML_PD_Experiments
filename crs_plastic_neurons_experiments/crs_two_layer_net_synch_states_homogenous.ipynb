# %%
import numpy as np
from google.colab import drive
import torch
import torch.nn as nn
import torch.optim as optim
drive.mount('/content/drive')

FOLDERNAME = 'Fusion AI/Rachel FusionAI Project/'
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

from Experiments.data import load_data
from Experiments.train import ThreeLayerNet, train_one_epoch
from Experiments.model import ThreeLayerNet
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-8913cea92cea> in <cell line: 12>()
#      10 sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))
#      11
# ---> 12 from Experiments.data import load_data
#      13 from Experiments.train import ThreeLayerNet, train_one_epoch
#      14 from Experiments.model import ThreeLayerNet
#
# ModuleNotFoundError: No module named 'Experiments.data'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
base_dir = '/content/drive/My Drive/Fusion AI/Rachel FusionAI Project/Experiments/synch_states_homogeneous/'
train_loader, test_loader = load_data(base_dir)

# %%
print(train_loader.dataset.data.shape)
print(train_loader.dataset.labels.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-67dd6ee7129b> in <cell line: 1>()
# ----> 1 print(train_loader.dataset.data.shape)
#       2 print(train_loader.dataset.labels.shape)
#
# NameError: name 'train_loader' is not defined

# %%
model = ThreeLayerNet()
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 10  # Adjust based on your needs
for epoch in range(epochs):
    print(f"Epoch {epoch + 1}")
    train_loss = train_one_epoch(epoch, train_loader, optimizer, model, criterion)  # You can add a tensorboard writer if needed
    print(f"Loss after epoch {epoch + 1}: {train_loss}")
